# %%
import pandas as pd

# %%
stations = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')

# %%
stations['Stop Name'] = stations['Stop Name'].str.lower()
stations['Daytime Routes'] = stations['Daytime Routes'].str.replace(' ','')

# %%
stations.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#                 Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  astoria - ditmars blvd       Q             NW  Elevated      40.775036
# 1            astoria blvd       Q             NW  Elevated      40.770258
# 2                   30 av       Q             NW  Elevated      40.766779
# 3                broadway       Q             NW  Elevated      40.761820
# 4                   36 av       Q             NW  Elevated      40.756804
#
#    GTFS Longitude
# 0      -73.912034
# 1      -73.917843
# 2      -73.921479
# 3      -73.925508
# 4      -73.929575

# %%
tstat = pd.read_pickle('/home/michael/Documents/Projects/Metis/01-Benson/distinctstationline.pkl')

# %%
tstat['stationlink'] = tstat['station'].str.lower()
tstat['stationlink'] = tstat['stationlink'].str.replace('.','')

# %%
tstat.head()
# Out:
#                 station  linename division      stationlink
# 69473            155 ST        BD      IND           155 st
# 45300             96 ST        BC      IND            96 st
# 28888              8 AV      ACEL      BMT             8 av
# 192935       ST. GEORGE         1      SRT        st george
# 94819   34 ST-HERALD SQ  BDFMNQRW      IND  34 st-herald sq

# %%
merged = pd.merge(tstat,stations,how='left',left_on=['stationlink','linename'],right_on=['Stop Name','Daytime Routes'])

# %%
missing = merged.drop_na()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-92e2ac9bc6d8> in <module>()
# ----> 1 missing = merged.drop_na()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'drop_na'

# %%
tstat[tstat['station']=='155 ST']
# Out:
#       station linename division
# 69473  155 ST       BD      IND
# 42923  155 ST        C      IND

# %%
stations[stations['Stop Name']=='155 St']
# Out:
#      Station ID  Complex ID GTFS Stop ID Division                Line  \
# 148         150         150          A11      IND  8th Av - Fulton St
# 218         220         220          D12      IND           Concourse
#
#     Stop Name Borough Daytime Routes Structure  GTFS Latitude  GTFS Longitude
# 148    155 St       M              C    Subway      40.830518      -73.941514
# 218    155 St       M            B D    Subway      40.830135      -73.938209

# %%
set(stations['Stop Name'])
# Out:
# {'1 av',
#  '103 st',
#  '103 st - corona plaza',
#  '104 st',
#  '110 st',
#  '111 st',
#  '116 st',
#  '116 st - columbia university',
#  '121 st',
#  '125 st',
#  '135 st',
#  '137 st - city college',
#  '138 st - grand concourse',
#  '14 st',
#  '14 st - union sq',
#  '145 st',
#  '149 st - grand concourse',
#  '15 st - prospect park',
#  '155 st',
#  '157 st',
#  '161 st - yankee stadium',
#  '163 st - amsterdam av',
#  '167 st',
#  '168 st',
#  '168 st - washington hts',
#  '169 st',
#  '170 st',
#  '174 st',
#  '174-175 sts',
#  '175 st',
#  '176 st',
#  '18 av',
#  '18 st',
#  '181 st',
#  '182-183 sts',
#  '183 st',
#  '190 st',
#  '191 st',
#  '2 av',
#  '20 av',
#  '207 st',
#  '21 st',
#  '21 st - queensbridge',
#  '215 st',
#  '219 st',
#  '225 st',
#  '23 st',
#  '231 st',
#  '233 st',
#  '238 st',
#  '25 av',
#  '25 st',
#  '28 st',
#  '3 av',
#  '3 av - 138 st',
#  '3 av - 149 st',
#  '30 av',
#  '33 st',
#  '34 st - 11 av',
#  '34 st - herald sq',
# ...
